# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

# %%
connection_string = "postgres:titota@localhost:5432/Canada_VSales"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['Canada_Vsales', 'Canada_Vsales_Bunits']

# %%
con=create_engine(f'postgresql://{connection_string}')

# %%
data=pd.read_sql('select * from "Canada_Vsales_Bunits"',con)

# %%
Canada_VSales=data

# %%
Canada_VSales.head()
# Out:
#   REF_DATE                        GEO    Vehicle type Origin of manufacture  \
# 0  2019-12  Newfoundland and Labrador  Passenger cars         North America
# 1  2019-12  Newfoundland and Labrador  Passenger cars        Total overseas
# 2  2019-12  Newfoundland and Labrador  Passenger cars                 Japan
# 3  2019-12  Newfoundland and Labrador  Passenger cars       Other countries
# 4  2019-12  Newfoundland and Labrador          Trucks         North America
#
#     Sales in dollars   Sales in units
# 0              3639.0             140
# 1              2584.0              75
# 2                 0.0               0
# 3                 0.0               0
# 4             43738.0             945

# %%
(
        Canada_VSales
    )
# Out:
#     REF_DATE                                   GEO    Vehicle type  \
# 0    2019-12             Newfoundland and Labrador  Passenger cars
# 1    2019-12             Newfoundland and Labrador  Passenger cars
# 2    2019-12             Newfoundland and Labrador  Passenger cars
# 3    2019-12             Newfoundland and Labrador  Passenger cars
# 4    2019-12             Newfoundland and Labrador          Trucks
# ..       ...                                   ...             ...
# 715  2020-11  British Columbia and the Territories  Passenger cars
# 716  2020-11  British Columbia and the Territories  Passenger cars
# 717  2020-11  British Columbia and the Territories  Passenger cars
# 718  2020-11  British Columbia and the Territories          Trucks
# 719  2020-11  British Columbia and the Territories          Trucks
#
#     Origin of manufacture   Sales in dollars   Sales in units
# 0           North America              3639.0             140
# 1          Total overseas              2584.0              75
# 2                   Japan                 0.0               0
# 3         Other countries                 0.0               0
# 4           North America             43738.0             945
# ..                    ...                 ...             ...
# 715        Total overseas             53277.0            1150
# 716                 Japan             13145.0             397
# 717       Other countries             40132.0             753
# 718         North America            453102.0            8608
# 719        Total overseas            146830.0            3199
#
# [720 rows x 6 columns]

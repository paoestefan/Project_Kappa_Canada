# %%
import pandas as pd

# %%
from sqlalchemy import create_engine

# %%
connection_string = "postgres:titota@localhost:5432/Canada_VSales"
engine = create_engine(f'postgresql://{connection_string}')

# %%
engine.table_names()
# Out:
# ['Canada_Vsales', 'Canada_Vsales_Bunits']

# %%
con=create_engine(f'postgresql://{connection_string}')

# %%
data=pd.read_sql('select * from "Canada_Vsales_Bunits"',con)

# %%
Canada_VSales=data

# %%
Canada_VSales.head()
# Out:
#   REF_DATE                        GEO    Vehicle type Origin of manufacture  \
# 0  2019-12  Newfoundland and Labrador  Passenger cars         North America
# 1  2019-12  Newfoundland and Labrador  Passenger cars        Total overseas
# 2  2019-12  Newfoundland and Labrador  Passenger cars                 Japan
# 3  2019-12  Newfoundland and Labrador  Passenger cars       Other countries
# 4  2019-12  Newfoundland and Labrador          Trucks         North America
#
#     Sales in dollars   Sales in units
# 0              3639.0             140
# 1              2584.0              75
# 2                 0.0               0
# 3                 0.0               0
# 4             43738.0             945

# %%
(
        Canada_VSales
    .to_json(orient="records")
    )
# Out:
# '[{"REF_DATE":"2019-12","GEO":"Newfoundland and Labrador","Vehicle type":"Passenger cars","Origin of manufacture":"North America"," Sales in dollars ":3639.0,"Sales in units":140},{"REF_DATE":"2019-12","GEO":"Newfoundland and Labrador","Vehicle type":"Passenger cars","Origin of manufacture":"Total overseas"," Sales in dollars ":2584.0,"Sales in units":75},{"REF_DATE":"2019-12","GEO":"Newfoundland and Labrador","Vehicle type":"Passenger cars","Origin of manufacture":"Japan"," Sales in dollars ":0.0,"Sales in units":0},{"REF_DATE":"2019-12","GEO":"Newfoundland and Labrador","Vehicle type":"Passenger cars","Origin of manufacture":"Other countries"," Sales in dollars ":0.0,"Sales in units":0},{"REF_DATE":"2019-12","GEO":"Newfoundland and Labrador","Vehicle type":"Trucks","Origin of manufacture":"North America"," Sales in dollars ":43738.0,"Sales in units":945},{"REF_DATE":"2019-12","GEO":"Newfoundland and Labrador","Vehicle type":"Trucks","Origin of manufacture":"Total overseas"," Sales in dollars ":7809.0,"Sales in units":219},{"REF_DATE":"2019-12","GEO":"Prince Edward Island","Vehicle type":"Passenger cars","Origin of manufacture":"North America"," Sales in dollars ":1790.0,"Sales in units":70},{"REF_DATE":"2019-12","GEO":"Prince Edward Island","Vehicle type":"Passenger cars","Origin of manufacture":"Total overseas"," Sales in dollars ":629.0,"Sales in units":23},{"REF_DATE":"2019-12","GEO":"Prince Edward Island","Vehicle type":"Passenger cars","Origin of manufacture":"Japan"," Sales in dollars ":0.0,"Sales in units":0},{"REF_DATE":"2019-12","GEO":"Prince Edward Island","Vehicle type":"Passenger cars","Origin of manufacture":"Other countries"," Sales in dollars ":0.0,"Sales in units":0},{"REF_DATE":"2019-12","GEO":"Prince Edward Island","Vehicle type":"Trucks","Origin of manufacture":"North America"," Sales in dollars ":13310.0,"Sales in units":303},{"REF_DATE":"2019-12","GEO":"Prince Edward Island","Vehicle type":"Trucks","Origin of manufacture":"Total overseas"," Sales in dollars ":2745.0,"Sales in units":78},{"REF_DATE":"2019-12","GEO":"Nova Scotia","Vehicle type":"Passenger cars","Origin of manufacture":"North America"," Sales in dollars ":9644.0,"Sales in units":339},{"REF_DATE":"2019-12","GEO":"Nova Scotia","Vehicle type":"Passenger cars","Origin of manufacture":"Total overseas"," Sales in dollars ":6909.0,"Sales in units":192},{"REF_DATE":"2019-12","GEO":"Nova Scotia","Vehicle type":"Passenger cars","Origin of manufacture":"Japan"," Sales in dollars ":1379.0,"Sales in units":45},{"REF_DATE":"2019-12","GEO":"Nova Scotia","Vehicle type":"Passenger cars","Origin of manufacture":"Other countries"," Sales in dollars ":5531.0,"Sales in units":147},{"REF_DATE":"2019-12","GEO":"Nova Scotia","Vehicle type":"Trucks","Origin of manufacture":"North America"," Sales in dollars ":71615.0,"Sales in units":1550},{"REF_DATE":"2019-12","GEO":"Nova Scotia","Vehicle type":"Trucks","Origin of manufacture":"Total overseas"," Sales in dollars ":19501.0,"Sales in units":515},{"REF_DATE":"2019-12","GEO":"New Brunswick","Vehicle type":"Passenger cars","Origin of manufacture":"North America"," Sales in dollars ":5895.0,"Sales in units":221},{"REF_DATE":"2019-12","GEO":"New Brunswick","Vehicle type":"Passenger cars","Origin of manufacture":"Total overseas"," Sales in dollars ":4474.0,"Sales in units":128},{"REF_DATE":"2019-12","GEO":"New Brunswick","Vehicle type":"Passenger cars","Origin of manufacture":"Japan"," Sales in dollars ":1426.0,"Sales in units":48},{"REF_DATE":"2019-12","GEO":"New Brunswick","Vehicle type":"Passenger cars","Origin of manufacture":"Other countries"," Sales in dollars ":3048.0,"Sales in units":80},{"REF_DATE":"2019-12","GEO":"New Brunswick","Vehicle type":"Trucks","Origin of manufacture":"North America"," Sales in dollars ":68903.0,"Sales in units":1384},{"REF_DATE":"2019-12","GEO":"New Brunswick","Vehicle type":"Trucks","Origin of manufacture":"Total overseas"," Sales in dollars ":14601.0,"Sales in units":395},{"REF_DATE": ...
